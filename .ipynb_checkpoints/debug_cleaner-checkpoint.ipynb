# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
from enum import Enum
from typing import Any, List
import math
import mtm
from mtm import matchTemplates
from mtm.detection import plotDetections
from skimage.data import coins

# %%
image = cv2.imread('dane/calib.png')
image_hsv = cv2.cvtColor(image, cv2.COLOR_BGR2HSV)
h_image,s_image,v_image = cv2.split(image_hsv)
template = cv2.imread('dane/white_long.png')
template_hsv = cv2.cvtColor(template, cv2.COLOR_BGR2HSV)
h_template,s_template,v_template = cv2.split(template_hsv)

# %%
image = cv2.imread('dane/calib.png')
image_gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
template = cv2.imread('dane/white_long.png')
template_gray = cv2.cvtColor(template, cv2.COLOR_BGR2GRAY)

# %%
# Function to rotate an image
def rotate_image_with_padding(image, angle):
    """
    Rotate the given image by the specified angle, ensuring no clipping occurs.

    Parameters:
        image (ndarray): Input image.
        angle (float): Angle by which the image is rotated.

    Returns:
        rotated_image (ndarray): Rotated image with no clipping.
    """
    # Get image dimensions
    height, width = image.shape
    diagonal = int(np.sqrt(height**2 + width**2))  # Compute diagonal length
    new_size = diagonal  # New canvas size

    # Add padding to fit the diagonal
    padded_image = cv2.copyMakeBorder(image, 
                                      (new_size - height) // 2, 
                                      (new_size - height) // 2, 
                                      (new_size - width) // 2, 
                                      (new_size - width) // 2, 
                                      cv2.BORDER_CONSTANT, 
                                      value=155) #Do zmiany wartości w zależności od tła!!

    # Perform the rotation
    center = (new_size // 2, new_size // 2)
    rotation_matrix = cv2.getRotationMatrix2D(center, angle, scale=1.0)
    rotated_image = cv2.warpAffine(padded_image, rotation_matrix, (new_size, new_size), flags=cv2.INTER_LINEAR, borderMode=cv2.BORDER_CONSTANT, borderValue=155)#Tutaj też do zmiany border value!!

    return rotated_image

# %%
def get_bounding_box(image):
    """
    Detect the bounding box of the largest object in the image.
    """
    # Threshold the image to create a binary mask
    _, binary = cv2.threshold(image,160, 255, cv2.THRESH_BINARY) #Threshold do zmiany w zależności od kanału i tła!!

    # Find contours
    contours, _ = cv2.findContours(binary, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_NONE)
    #cv2.drawContours(image, contours, -1, (0, 255, 0), 3) 
  
    #cv2.imshow('Contours', image) 
    #cv2.waitKey(0) 
    #cv2.destroyAllWindows() 
    # Filter and select the largest contour by area
    largest_contour = max(contours, key=cv2.contourArea)
    if largest_contour is None:
        return None  # Return None if no contour is detected

    # Get bounding rectangle
    x, y, w, h = cv2.boundingRect(largest_contour)

    return x, y, w, h

# %%
# Rotate the s_template image at specific angles
angles = range(15, 360, 15)  # Angles: 15°, 30°, 45°, ..., 345°
listTemplates = [template_gray]
listLabels    = ["Temp0"]

f, axarr = plt.subplots(1,24)
axarr[0].imshow(template_gray)

for i,angle in enumerate(angles):
    rotated = rotate_image_with_padding(template_gray, angle)

    # Detect the bounding box for the pill
    x, y, w, h = get_bounding_box(rotated)

    # Crop the image using the bounding box
    cropped = rotated[y:y+h, x:x+w]
    listTemplates.append(cropped)
    listLabels.append(str(angle))
    axarr[i+1].imshow(cropped)

# %%
listDetections = matchTemplates(image_gray, 
                                listTemplates,
                                listLabels,
                                scoreThreshold=0.7, 
                                maxOverlap=0.4)

print("Found {} hits".format( len(listDetections) ) )
listDetections
# Out:
# Found 30 hits
# [(BoundingBox, score:0.86, xywh:(np.int64(906), np.int64(623), 150, 191), index:2, 30),
#  (BoundingBox, score:0.80, xywh:(np.int64(1462), np.int64(506), 78, 198), index:12, 180),
#  (BoundingBox, score:0.76, xywh:(np.int64(1525), np.int64(390), 80, 207), index:0, Temp0),
#  (BoundingBox, score:0.76, xywh:(np.int64(1747), np.int64(353), 80, 207), index:0, Temp0),
#  (BoundingBox, score:0.74, xywh:(np.int64(1087), np.int64(451), 198, 78), index:18, 270),
#  (BoundingBox, score:0.74, xywh:(np.int64(1593), np.int64(788), 80, 207), index:0, Temp0),
#  (BoundingBox, score:0.73, xywh:(np.int64(692), np.int64(819), 198, 78), index:6, 90),
#  (BoundingBox, score:0.73, xywh:(np.int64(2091), np.int64(294), 78, 198), index:12, 180),
#  (BoundingBox, score:0.73, xywh:(np.int64(709), np.int64(940), 198, 78), index:18, 270),
#  (BoundingBox, score:0.73, xywh:(np.int64(1734), np.int64(772), 78, 198), index:12, 180),
#  (BoundingBox, score:0.72, xywh:(np.int64(835), np.int64(947), 78, 198), index:12, 180),
#  (BoundingBox, score:0.72, xywh:(np.int64(1759), np.int64(425), 80, 207), index:0, Temp0),
#  (BoundingBox, score:0.72, xywh:(np.int64(1815), np.int64(740), 80, 207), index:0, Temp0),
#  (BoundingBox, score:0.71, xywh:(np.int64(760), np.int64(1095), 80, 207), index:0, Temp0),
#  (BoundingBox, score:0.71, xywh:(np.int64(737), np.int64(966), 80, 207), index:0, Temp0),
#  (BoundingBox, score:0.71, xywh:(np.int64(845), np.int64(1020), 78, 198), index:12, 180),
#  (BoundingBox, score:0.71, xywh:(np.int64(1664), np.int64(375), 78, 198), index:12, 180),
#  (BoundingBox, score:0.71, xywh:(np.int64(1160), np.int64(855), 198, 78), index:18, 270),
#  (BoundingBox, score:0.71, xywh:(np.int64(765), np.int64(1328), 198, 78), index:18, 270),
#  (BoundingBox, score:0.71, xywh:(np.int64(1099), np.int64(482), 198, 78), index:6, 90),
#  (BoundingBox, score:0.70, xywh:(np.int64(1125), np.int64(604), 202, 105), index:17, 255),
#  (BoundingBox, score:0.70, xywh:(np.int64(2195), np.int64(248), 80, 207), index:0, Temp0),
#  (BoundingBox, score:0.70, xywh:(np.int64(796), np.int64(678), 78, 198), index:12, 180),
#  (BoundingBox, score:0.70, xywh:(np.int64(948), np.int64(931), 202, 105), index:5, 75),
#  (BoundingBox, score:0.70, xywh:(np.int64(638), np.int64(535), 198, 78), index:18, 270),
#  (BoundingBox, score:0.70, xywh:(np.int64(772), np.int64(543), 78, 198), index:12, 180),
#  (BoundingBox, score:0.70, xywh:(np.int64(863), np.int64(1086), 78, 198), index:12, 180),
#  (BoundingBox, score:0.70, xywh:(np.int64(1516), np.int64(827), 78, 198), index:12, 180),
#  (BoundingBox, score:0.70, xywh:(np.int64(1908), np.int64(479), 78, 198), index:12, 180),
#  (BoundingBox, score:0.70, xywh:(np.int64(2033), np.int64(696), 80, 207), index:0, Temp0)]

# %%
plotDetections(image_gray, listDetections)

# %% [markdown]
# ## Detect all elongated pills
